# %%
from rdflib import Graph
dataset_folder = "dataset"
output_folder = "ttl_dataset"

# %%
filename = "big_one"

# %%
g = Graph()
g = g.parse(f"{dataset_folder}/{filename}.xml", format="xml")

# %%
g.serialize(f"{output_folder}/{filename}.ttl", format="turtle")
