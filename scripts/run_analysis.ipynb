# %%
import pandas as pd
import numpy as np

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import pairwise_tukeyhsd

from statsmodels.formula.api import mixedlm
from scipy.stats import wilcoxon, ttest_rel
from itertools import combinations

from scipy.stats import ConstantInputWarning
import warnings
warnings.filterwarnings("ignore", category=ConstantInputWarning)

# %%
def detect_factors_and_metrics(df):
    """
    Clean a sheet:
      - drop all-NaN rows
      - strip column names
      - forward-fill factor columns (KG, Model, Complexity)
      - cast factors to categorical
      - detect numeric metric columns automatically
    """
    df = df.dropna(how="all").copy()
    df.columns = [str(c).strip() for c in df.columns]

    factor_candidates = ["KG", "Model", "Complexity"]
    factors = [c for c in factor_candidates if c in df.columns]

    # Forward-fill factor columns (your sheets have KG/Model only on first row of a block)
    for f in factors:
        df[f] = df[f].ffill()
        df[f] = df[f].astype("category")

    # Metrics = numeric columns that are not factors and not totally NaN
    metric_cols = []
    for c in df.columns:
        if c in factors:
            continue
        if pd.api.types.is_numeric_dtype(df[c]) and df[c].notna().any():
            metric_cols.append(c)

    return df, factors, metric_cols

# %%
def run_anova_and_posthoc(df, factors, metric, sheet_name):
    """Run ANOVA, Tukey and Wilcoxon tests for one metric on one sheet."""
    data = df.dropna(subset=[metric]).copy()

    print("\n" + "=" * 120)
    print(f"SHEET: {sheet_name} | METRIC: {metric}")
    print("=" * 120)

    # If metric is constant, no point in testing anything
    if data[metric].nunique() < 2:
        print("Metric is constant across rows; skipping statistical tests.")
        return

    has_kg = "KG" in factors
    has_complexity = "Complexity" in factors
    has_model = "Model" in factors

    # -------------------- ANOVA / mixed model --------------------
    anova_done = False

    if has_kg or has_complexity:
        try:
            # Build formula depending on which factors exist
            if has_kg and has_complexity:
                # 2-way with interaction, plus Model as a blocking factor if present
                formula = f"{metric} ~ C(KG) * C(Complexity)"
                if has_model:
                    formula += " + C(Model)"
            elif has_kg:
                formula = f"{metric} ~ C(KG)"
                if has_model:
                    formula += " + C(Model)"
            else:  # only complexity
                formula = f"{metric} ~ C(Complexity)"
                if has_model:
                    formula += " + C(Model)"

            print(f"Attempting ANOVA with formula: {formula}")
            model = smf.ols(formula, data=data).fit()
            anova_table = anova_lm(model, typ=2)

            # Add eta-squared effect size
            ss_total = anova_table["sum_sq"].sum()
            anova_table["eta_sq"] = anova_table["sum_sq"] / ss_total

            print("\nANOVA table:")
            print(anova_table)
            anova_done = True

        except Exception as e:
            print("\n⚠️ ANOVA failed, attempting mixed-effects model instead.")
            print(f"Reason: {e}")

            # Mixed model: KG as fixed effect, Model as random effect (if both present)
            if has_kg and has_model:
                try:
                    print("\nMixed-effects model: metric ~ KG with random intercept per Model")
                    mx = mixedlm(f"{metric} ~ C(KG)", data=data, groups=data["Model"])
                    res = mx.fit()
                    print(res.summary())
                except Exception as e2:
                    print("Mixed-effects model also failed:", e2)
            else:
                print("No appropriate structure for mixed-effects model; skipping.")

    else:
        print("No KG or Complexity columns found; skipping ANOVA/mixed.")

    # -------------------- Tukey HSD: KG --------------------
    if has_kg and data["KG"].nunique() > 1:
        try:
            print("\nPost-hoc: KG (Tukey HSD)")
            tuk_kg = pairwise_tukeyhsd(endog=data[metric],
                                       groups=data["KG"],
                                       alpha=0.05)
            print(tuk_kg)
        except Exception as e:
            print("Tukey for KG failed:", e)

    # -------------------- Tukey HSD: Complexity --------------------
    if has_complexity and data["Complexity"].nunique() > 1:
        try:
            print("\nPost-hoc: Complexity (Tukey HSD)")
            tuk_c = pairwise_tukeyhsd(endog=data[metric],
                                      groups=data["Complexity"],
                                      alpha=0.05)
            print(tuk_c)
        except Exception as e:
            print("Tukey for Complexity failed:", e)

        # KG × Complexity combos
        if has_kg:
            try:
                print("\nPost-hoc: KG × Complexity combinations (Tukey HSD)")
                combos = data["KG"].astype(str) + "_" + data["Complexity"].astype(str)
                tuk_kc = pairwise_tukeyhsd(endog=data[metric],
                                           groups=combos,
                                           alpha=0.05)
                print(tuk_kc)
            except Exception as e:
                print("Tukey for KG×Complexity combos failed:", e)

    # -------------------- Wilcoxon: KG (paired across models) --------------------
    # Here we treat each model as a subject, compare Big vs Small (or two KG levels)
    if has_kg and has_model:
        wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)

        if wide_kg.shape[1] >= 2:
            # If more than 2 levels (not in your current file, but just in case),
            # compare them pairwise.
            levels = list(wide_kg.columns)
            print("\nWilcoxon signed-rank tests for KG (pairwise across models):")
            for a, b in combinations(levels, 2):
                sub = wide_kg[[a, b]].dropna()
                if len(sub) > 1:
                    try:
                        w_stat, w_p = wilcoxon(sub[a], sub[b])
                        print(f"  {a} vs {b}: n = {len(sub)}, W = {w_stat:.4f}, p = {w_p:.4g}")
                        # Optional: paired t-test for reference
                        t_stat, t_p = ttest_rel(sub[a], sub[b])
                        print(f"    (paired t-test: t = {t_stat:.4f}, p = {t_p:.4g})")
                    except Exception as e:
                        print(f"  {a} vs {b}: Wilcoxon failed:", e)
                else:
                    print(f"  {a} vs {b}: not enough paired data, skipped.")
        else:
            print("\nWilcoxon KG: skipped (KG does not have at least 2 levels).")

    # -------------------- Wilcoxon: Complexity (pairwise across models) --------------------
    if has_complexity and has_model:
        wide_c = data.pivot_table(index="Model",
                                  columns="Complexity",
                                  values=metric)

        levels = [lvl for lvl in wide_c.columns if wide_c[lvl].notna().any()]
        if len(levels) >= 2:
            print("\nWilcoxon signed-rank tests for Complexity (pairwise across models):")
            for a, b in combinations(levels, 2):
                sub = wide_c[[a, b]].dropna()
                if len(sub) > 1:
                    try:
                        w_stat, w_p = wilcoxon(sub[a], sub[b])
                        print(f"  {a} vs {b}: n = {len(sub)}, W = {w_stat:.4f}, p = {w_p:.4g}")
                        # Optional: paired t-test for reference
                        t_stat, t_p = ttest_rel(sub[a], sub[b])
                        print(f"    (paired t-test: t = {t_stat:.4f}, p = {t_p:.4g})")
                    except Exception as e:
                        print(f"  {a} vs {b}: Wilcoxon failed:", e)
                else:
                    print(f"  {a} vs {b}: not enough paired data, skipped.")
        else:
            print("\nWilcoxon Complexity: skipped (fewer than 2 complexity levels with data).")

# %%
def analyze_excel(file_path):
    xls = pd.ExcelFile(file_path)
    print(f"Found sheets: {xls.sheet_names}")
    

    # for sheet in xls.sheet_names:
    for sheet in ['H1-AM&C']:
        print("\n" + "#" * 120)
        print(f"ANALYZING SHEET: {sheet}")
        print("#" * 120)

        df_raw = xls.parse(sheet)
        df, factors, metric_cols = detect_factors_and_metrics(df_raw)

        print(f"Detected factor columns: {factors}")
        print(f"Detected metric columns: {metric_cols}")

        if not metric_cols:
            print("No numeric metrics detected, skipping sheet.")
            continue

        for metric in metric_cols:
            run_anova_and_posthoc(df, factors, metric, sheet)

# %%
# ---------------- CONFIG ----------------
EXCEL_FILE = "all_models_consolidated_results.xlsx" 
# ----------------------------------------

# %%
analyze_excel(EXCEL_FILE)
# Out:
# Found sheets: ['Screen', 'All_Screen', 'Screen with C', 'H1-AM', 'H1-AM&C', 'H2-AM', 'H2-AM&C']
#
# ########################################################################################################################
# ANALYZING SHEET: H1-AM&C
# ########################################################################################################################
# Detected factor columns: ['KG', 'Model', 'Complexity']
# Detected metric columns: ['rows', 'vars', 'latency_p50_ms', 'latency_p95_ms', 'latency_mean_ms', 'lexical_query_overlap', 'semantic_similarity_to_CQ', 'semantic_soft_coverage_to_CQ', 'tuple_cohesion', 'determinism_score', 'satisfiability_binding_score', 'h1_overall', 'semantic_diversity_score', 'syntax_ok_rate', 'satisfiable_rate', 'deterministic_rate']
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: rows
# ========================================================================================================================
# Attempting ANOVA with formula: rows ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                            sum_sq    df         F    PR(>F)    eta_sq
# C(KG)                3.846991e+07   1.0  2.012802  0.176420  0.059953
# C(Complexity)        1.164838e+08   2.0  3.047301  0.077517  0.181532
# C(Model)             1.725621e+08   3.0  3.009568  0.063262  0.268927
# C(KG):C(Complexity)  2.746420e+07   2.0  0.718484  0.503526  0.042801
# Residual             2.866892e+08  15.0       NaN       NaN  0.446787
#
# Post-hoc: KG (Tukey HSD)
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
# group1 group2  meandiff  p-adj    lower     upper   reject
# ----------------------------------------------------------
#    Big  Small -2532.1238 0.2488 -6965.4087 1901.161  False
# ----------------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
#  group1   group2   meandiff  p-adj     lower      upper    reject
# -----------------------------------------------------------------
#  Complex Moderate  3934.2248 0.2788   -2368.314 10236.7636  False
#  Complex   Simple -1231.6557 0.8756  -7534.1945  5070.8831  False
# Moderate   Simple -5165.8804 0.1214 -11468.4192  1136.6584  False
# -----------------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#     group1         group2      meandiff  p-adj     lower      upper    reject
# -----------------------------------------------------------------------------
#    Big_Complex   Big_Moderate  6328.8323 0.5062  -5022.1287 17679.7934  False
#    Big_Complex     Big_Simple   -955.725 0.9998 -12306.6861 10395.2361  False
#    Big_Complex  Small_Complex   -751.765 0.9999 -12102.7261 10599.1961  False
#    Big_Complex Small_Moderate   787.8522 0.9999 -10563.1089 12138.8133  False
#    Big_Complex   Small_Simple -2259.3514 0.9869 -13610.3125  9091.6097  False
#   Big_Moderate     Big_Simple -7284.5573 0.3597 -18635.5184  4066.4038  False
#   Big_Moderate  Small_Complex -7080.5973 0.3889 -18431.5584  4270.3638  False
#   Big_Moderate Small_Moderate -5540.9802  0.638 -16891.9412  5809.9809  False
#   Big_Moderate   Small_Simple -8588.1837 0.2063 -19939.1448  2762.7774  False
#     Big_Simple  Small_Complex     203.96    1.0 -11147.0011 11554.9211  False
#     Big_Simple Small_Moderate  1743.5771  0.996  -9607.3839 13094.5382  False
#     Big_Simple   Small_Simple -1303.6264  0.999 -12654.5875 10047.3347  False
#  Small_Complex Small_Moderate  1539.6172 0.9978  -9811.3439 12890.5782  False
#  Small_Complex   Small_Simple -1507.5864  0.998 -12858.5475  9843.3747  False
# Small_Moderate   Small_Simple -3047.2036 0.9529 -14398.1646  8303.7575  False
# -----------------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 2.0000, p = 0.375
#     (paired t-test: t = 1.3519, p = 0.2693)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 1.0000, p = 0.25
#     (paired t-test: t = -1.3663, p = 0.2652)
#   Complex vs Simple: n = 4, W = 3.0000, p = 0.625
#     (paired t-test: t = 0.7854, p = 0.4895)
#   Moderate vs Simple: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = 2.6409, p = 0.0776)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: vars
# ========================================================================================================================
# Attempting ANOVA with formula: vars ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                         sum_sq    df          F    PR(>F)    eta_sq
# C(KG)                 0.003413   1.0   0.009754  0.922636  0.000099
# C(Complexity)        10.245202   2.0  14.641214  0.000298  0.295920
# C(Model)             17.708236   3.0  16.870991  0.000045  0.511480
# C(KG):C(Complexity)   1.416575   2.0   2.024399  0.166601  0.040916
# Residual              5.248132  15.0        NaN       NaN  0.151586
#
# Post-hoc: KG (Tukey HSD)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#    Big  Small   0.0238 0.9633 -1.0382 1.0859  False
# ---------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
#  group1   group2  meandiff p-adj   lower   upper  reject
# --------------------------------------------------------
#  Complex Moderate  -1.5265 0.0258 -2.8844 -0.1687   True
#  Complex   Simple  -1.1795 0.0964 -2.5373  0.1783  False
# Moderate   Simple   0.3471 0.7976 -1.0108  1.7049  False
# --------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#     group1         group2     meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------
#    Big_Complex   Big_Moderate  -1.9608 0.1895 -4.4986  0.577  False
#    Big_Complex     Big_Simple   -1.749 0.2892 -4.2868 0.7888  False
#    Big_Complex  Small_Complex  -0.6453 0.9623 -3.1831 1.8925  False
#    Big_Complex Small_Moderate  -1.7376 0.2955 -4.2754 0.8002  False
#    Big_Complex   Small_Simple  -1.2553 0.6256 -3.7931 1.2825  False
#   Big_Moderate     Big_Simple   0.2118 0.9998  -2.326 2.7496  False
#   Big_Moderate  Small_Complex   1.3155 0.5803 -1.2223 3.8533  False
#   Big_Moderate Small_Moderate   0.2232 0.9997 -2.3146  2.761  False
#   Big_Moderate   Small_Simple   0.7055 0.9457 -1.8323 3.2433  False
#     Big_Simple  Small_Complex   1.1037 0.7367 -1.4342 3.6415  False
#     Big_Simple Small_Moderate   0.0114    1.0 -2.5264 2.5492  False
#     Big_Simple   Small_Simple   0.4937 0.9882 -2.0441 3.0315  False
#  Small_Complex Small_Moderate  -1.0923 0.7447 -3.6301 1.4455  False
#  Small_Complex   Small_Simple    -0.61 0.9702 -3.1478 1.9278  False
# Small_Moderate   Small_Simple   0.4823 0.9894 -2.0555 3.0201  False
# -------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 5.0000, p = 1
#     (paired t-test: t = -0.2071, p = 0.8492)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = 6.6774, p = 0.006849)
#   Complex vs Simple: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = 3.4501, p = 0.04093)
#   Moderate vs Simple: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = -0.7395, p = 0.5132)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: latency_p50_ms
# ========================================================================================================================
# Attempting ANOVA with formula: latency_p50_ms ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                            sum_sq    df         F    PR(>F)    eta_sq
# C(KG)                6.907891e+04   1.0  0.048249  0.829099  0.001880
# C(Complexity)        6.488076e+05   2.0  0.226586  0.799931  0.017660
# C(Model)             9.768473e+06   3.0  2.274322  0.121742  0.265894
# C(KG):C(Complexity)  4.776275e+06   2.0  1.668037  0.221762  0.130008
# Residual             2.147558e+07  15.0       NaN       NaN  0.584557
#
# Post-hoc: KG (Tukey HSD)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#    Big  Small 107.2994 0.8406 -985.7644 1200.3632  False
# --------------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#  group1   group2   meandiff p-adj    lower      upper   reject
# --------------------------------------------------------------
#  Complex Moderate    5.8034    1.0 -1646.3449 1657.9517  False
#  Complex   Simple -345.8477 0.8587  -1997.996 1306.3006  False
# Moderate   Simple -351.6511 0.8544 -2003.7994 1300.4972  False
# --------------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#             Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================================
#     group1         group2      meandiff  p-adj    lower      upper   reject
# ---------------------------------------------------------------------------
#    Big_Complex   Big_Moderate  -128.8981    1.0 -3089.5754 2831.7791  False
#    Big_Complex     Big_Simple   525.9198 0.9922 -2434.7574 3486.5971  False
#    Big_Complex  Small_Complex   598.6767  0.986 -2362.0005 3559.3539  False
#    Big_Complex Small_Moderate   739.1817 0.9651 -2221.4956 3699.8589  False
#    Big_Complex   Small_Simple  -618.9386 0.9837 -3579.6158 2341.7386  False
#   Big_Moderate     Big_Simple    654.818 0.9792 -2305.8593 3615.4952  False
#   Big_Moderate  Small_Complex   727.5748 0.9673 -2233.1024 3688.2521  False
#   Big_Moderate Small_Moderate   868.0798 0.9329 -2092.5974  3828.757  False
#   Big_Moderate   Small_Simple  -490.0405 0.9943 -3450.7177 2470.6368  False
#     Big_Simple  Small_Complex    72.7569    1.0 -2887.9204 3033.4341  False
#     Big_Simple Small_Moderate   213.2618 0.9999 -2747.4154 3173.9391  False
#     Big_Simple   Small_Simple -1144.8584 0.8174 -4105.5356 1815.8188  False
#  Small_Complex Small_Moderate    140.505    1.0 -2820.1723 3101.1822  False
#  Small_Complex   Small_Simple -1217.6153 0.7776 -4178.2925 1743.0619  False
# Small_Moderate   Small_Simple -1358.1202 0.6934 -4318.7975  1602.557  False
# ---------------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 5.0000, p = 1
#     (paired t-test: t = -0.3688, p = 0.7367)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = -0.0149, p = 0.989)
#   Complex vs Simple: n = 4, W = 3.0000, p = 0.625
#     (paired t-test: t = 0.8602, p = 0.4529)
#   Moderate vs Simple: n = 4, W = 5.0000, p = 1
#     (paired t-test: t = 0.4895, p = 0.658)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: latency_p95_ms
# ========================================================================================================================
# Attempting ANOVA with formula: latency_p95_ms ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                            sum_sq    df         F    PR(>F)    eta_sq
# C(KG)                5.586181e+04   1.0  0.033879  0.856430  0.001330
# C(Complexity)        8.622086e+05   2.0  0.261455  0.773368  0.020522
# C(Model)             1.128211e+07   3.0  2.280781  0.121019  0.268533
# C(KG):C(Complexity)  5.080751e+06   2.0  1.540679  0.246293  0.120930
# Residual             2.473301e+07  15.0       NaN       NaN  0.588686
#
# Post-hoc: KG (Tukey HSD)
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
# group1 group2 meandiff p-adj    lower      upper   reject
# ---------------------------------------------------------
#    Big  Small  96.4899 0.8657 -1072.7484 1265.7282  False
# ---------------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#  group1   group2   meandiff p-adj    lower      upper   reject
# --------------------------------------------------------------
#  Complex Moderate   81.4663 0.9926 -1682.7558 1845.6884  False
#  Complex   Simple -355.1034 0.8686 -2119.3255 1409.1187  False
# Moderate   Simple -436.5697 0.8088 -2200.7918 1327.6524  False
# --------------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#             Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================================
#     group1         group2      meandiff  p-adj    lower      upper   reject
# ---------------------------------------------------------------------------
#    Big_Complex   Big_Moderate   -80.4589    1.0 -3259.1613 3098.2434  False
#    Big_Complex     Big_Simple   529.8409 0.9942 -2648.8614 3708.5432  False
#    Big_Complex  Small_Complex   578.5026 0.9913 -2600.1997 3757.2049  False
#    Big_Complex Small_Moderate   821.8941 0.9596 -2356.8082 4000.5964  False
#    Big_Complex   Small_Simple   -661.545 0.9841 -3840.2473 2517.1573  False
#   Big_Moderate     Big_Simple   610.2998 0.9889 -2568.4025 3789.0021  False
#   Big_Moderate  Small_Complex   658.9615 0.9843 -2519.7408 3837.6638  False
#   Big_Moderate Small_Moderate    902.353  0.941 -2276.3493 4081.0554  False
#   Big_Moderate   Small_Simple  -581.0861 0.9911 -3759.7884 2597.6162  False
#     Big_Simple  Small_Complex    48.6617    1.0 -3130.0406  3227.364  False
#     Big_Simple Small_Moderate   292.0532 0.9997 -2886.6491 3470.7556  False
#     Big_Simple   Small_Simple -1191.3859 0.8354 -4370.0882 1987.3164  False
#  Small_Complex Small_Moderate   243.3915 0.9999 -2935.3108 3422.0938  False
#  Small_Complex   Small_Simple -1240.0476  0.812 -4418.7499 1938.6547  False
# Small_Moderate   Small_Simple -1483.4391 0.6785 -4662.1415 1695.2632  False
# ---------------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 5.0000, p = 1
#     (paired t-test: t = -0.2922, p = 0.7892)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = -0.1867, p = 0.8638)
#   Complex vs Simple: n = 4, W = 3.0000, p = 0.625
#     (paired t-test: t = 0.8761, p = 0.4455)
#   Moderate vs Simple: n = 4, W = 5.0000, p = 1
#     (paired t-test: t = 0.5639, p = 0.6122)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: latency_mean_ms
# ========================================================================================================================
# Attempting ANOVA with formula: latency_mean_ms ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                            sum_sq    df         F    PR(>F)    eta_sq
# C(KG)                8.753875e+04   1.0  0.060164  0.809562  0.002345
# C(Complexity)        7.620776e+05   2.0  0.261881  0.773049  0.020415
# C(Model)             9.934736e+06   3.0  2.275985  0.121555  0.266135
# C(KG):C(Complexity)  4.720165e+06   2.0  1.622039  0.230287  0.126445
# Residual             2.182514e+07  15.0       NaN       NaN  0.584660
#
# Post-hoc: KG (Tukey HSD)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#    Big  Small 120.7882 0.8222 -980.7825 1222.3589  False
# --------------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#  group1   group2   meandiff p-adj    lower      upper   reject
# --------------------------------------------------------------
#  Complex Moderate   37.5456 0.9982 -1625.5119 1700.6032  False
#  Complex   Simple -357.8335 0.8514  -2020.891 1305.2241  False
# Moderate   Simple -395.3791  0.822 -2058.4367 1267.6785  False
# --------------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#             Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================================
#     group1         group2      meandiff  p-adj    lower      upper   reject
# ---------------------------------------------------------------------------
#    Big_Complex   Big_Moderate   -97.0208    1.0 -3082.0378 2887.9962  False
#    Big_Complex     Big_Simple   508.3981 0.9936 -2476.6189 3493.4151  False
#    Big_Complex  Small_Complex    608.565 0.9854  -2376.452  3593.582  False
#    Big_Complex Small_Moderate    780.677 0.9576   -2204.34  3765.694  False
#    Big_Complex   Small_Simple     -615.5 0.9847  -3600.517  2369.517  False
#   Big_Moderate     Big_Simple   605.4189 0.9858 -2379.5981 3590.4359  False
#   Big_Moderate  Small_Complex   705.5857 0.9723 -2279.4313 3690.6027  False
#   Big_Moderate Small_Moderate   877.6978 0.9322 -2107.3192 3862.7148  False
#   Big_Moderate   Small_Simple  -518.4793 0.9929 -3503.4963 2466.5377  False
#     Big_Simple  Small_Complex   100.1669    1.0 -2884.8501 3085.1839  False
#     Big_Simple Small_Moderate   272.2789 0.9997 -2712.7381 3257.2959  False
#     Big_Simple   Small_Simple -1123.8981 0.8328 -4108.9151 1861.1189  False
#  Small_Complex Small_Moderate    172.112    1.0  -2812.905  3157.129  False
#  Small_Complex   Small_Simple  -1224.065 0.7796  -4209.082  1760.952  False
# Small_Moderate   Small_Simple  -1396.177 0.6766  -4381.194 1588.8399  False
# ---------------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 5.0000, p = 1
#     (paired t-test: t = -0.4006, p = 0.7156)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = -0.0916, p = 0.9328)
#   Complex vs Simple: n = 4, W = 3.0000, p = 0.625
#     (paired t-test: t = 0.9188, p = 0.426)
#   Moderate vs Simple: n = 4, W = 5.0000, p = 1
#     (paired t-test: t = 0.5431, p = 0.6248)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: lexical_query_overlap
# ========================================================================================================================
# Attempting ANOVA with formula: lexical_query_overlap ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                        sum_sq    df         F    PR(>F)    eta_sq
# C(KG)                0.001285   1.0  2.213398  0.157536  0.080658
# C(Complexity)        0.003768   2.0  3.245106  0.067434  0.236507
# C(Model)             0.001340   3.0  0.769671  0.528711  0.084142
# C(KG):C(Complexity)  0.000830   2.0  0.714642  0.505295  0.052084
# Residual             0.008708  15.0       NaN       NaN  0.546609
#
# Post-hoc: KG (Tukey HSD)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#    Big  Small   0.0146 0.1786 -0.0072 0.0365  False
# ---------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#  Complex Moderate   0.0276 0.0792 -0.0028 0.0579  False
#  Complex   Simple   0.0021 0.9833 -0.0282 0.0324  False
# Moderate   Simple  -0.0255 0.1106 -0.0558 0.0049  False
# -------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#     group1         group2     meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------
#    Big_Complex   Big_Moderate   0.0251 0.6669  -0.028 0.0782  False
#    Big_Complex     Big_Simple   0.0132 0.9661 -0.0399 0.0663  False
#    Big_Complex  Small_Complex   0.0204 0.8221 -0.0327 0.0735  False
#    Big_Complex Small_Moderate   0.0504 0.0685 -0.0027 0.1035  False
#    Big_Complex   Small_Simple   0.0114 0.9816 -0.0417 0.0645  False
#   Big_Moderate     Big_Simple  -0.0119 0.9776  -0.065 0.0412  False
#   Big_Moderate  Small_Complex  -0.0047 0.9997 -0.0578 0.0484  False
#   Big_Moderate Small_Moderate   0.0253 0.6605 -0.0278 0.0784  False
#   Big_Moderate   Small_Simple  -0.0137   0.96 -0.0668 0.0394  False
#     Big_Simple  Small_Complex   0.0072 0.9978 -0.0459 0.0603  False
#     Big_Simple Small_Moderate   0.0372 0.2729 -0.0159 0.0903  False
#     Big_Simple   Small_Simple  -0.0018    1.0 -0.0548 0.0513  False
#  Small_Complex Small_Moderate     0.03 0.4913 -0.0231 0.0831  False
#  Small_Complex   Small_Simple   -0.009 0.9938  -0.062 0.0441  False
# Small_Moderate   Small_Simple   -0.039 0.2315 -0.0921 0.0141  False
# -------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 1.0000, p = 0.25
#     (paired t-test: t = -1.7677, p = 0.1753)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = -3.8542, p = 0.03085)
#   Complex vs Simple: n = 4, W = 5.0000, p = 1
#     (paired t-test: t = -0.1354, p = 0.9009)
#   Moderate vs Simple: n = 4, W = 2.0000, p = 0.375
#     (paired t-test: t = 1.3682, p = 0.2647)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: semantic_similarity_to_CQ
# ========================================================================================================================
# Attempting ANOVA with formula: semantic_similarity_to_CQ ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                        sum_sq    df         F    PR(>F)    eta_sq
# C(KG)                0.015364   1.0  0.714578  0.411210  0.031166
# C(Complexity)        0.046551   2.0  1.082523  0.363787  0.094428
# C(Model)             0.072184   3.0  1.119072  0.372579  0.146424
# C(KG):C(Complexity)  0.036361   2.0  0.845568  0.448787  0.073759
# Residual             0.322515  15.0       NaN       NaN  0.654223
#
# Post-hoc: KG (Tukey HSD)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#    Big  Small   0.0506 0.4093 -0.0741 0.1754  False
# ---------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#  Complex Moderate  -0.0921 0.4306 -0.2759 0.0916  False
#  Complex   Simple   0.0026 0.9993 -0.1812 0.1863  False
# Moderate   Simple   0.0947 0.4115 -0.0891 0.2784  False
# -------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#     group1         group2     meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------
#    Big_Complex   Big_Moderate  -0.1825 0.5233 -0.5153 0.1503  False
#    Big_Complex     Big_Simple  -0.0163    1.0 -0.3491 0.3165  False
#    Big_Complex  Small_Complex  -0.0222 0.9999  -0.355 0.3106  False
#    Big_Complex Small_Moderate   -0.024 0.9999 -0.3567 0.3088  False
#    Big_Complex   Small_Simple  -0.0008    1.0 -0.3336  0.332  False
#   Big_Moderate     Big_Simple   0.1662 0.6165 -0.1666  0.499  False
#   Big_Moderate  Small_Complex   0.1603 0.6504 -0.1725  0.493  False
#   Big_Moderate Small_Moderate   0.1585 0.6603 -0.1742 0.4913  False
#   Big_Moderate   Small_Simple   0.1817 0.5278 -0.1511 0.5145  False
#     Big_Simple  Small_Complex  -0.0059    1.0 -0.3387 0.3269  False
#     Big_Simple Small_Moderate  -0.0077    1.0 -0.3404 0.3251  False
#     Big_Simple   Small_Simple   0.0155    1.0 -0.3173 0.3483  False
#  Small_Complex Small_Moderate  -0.0018    1.0 -0.3345  0.331  False
#  Small_Complex   Small_Simple   0.0214 0.9999 -0.3114 0.3542  False
# Small_Moderate   Small_Simple   0.0232 0.9999 -0.3096 0.3559  False
# -------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = -0.7963, p = 0.4841)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = 0.9433, p = 0.4151)
#   Complex vs Simple: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = -0.4756, p = 0.6668)
#   Moderate vs Simple: n = 4, W = 1.0000, p = 0.25
#     (paired t-test: t = -1.0252, p = 0.3807)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: semantic_soft_coverage_to_CQ
# ========================================================================================================================
# Attempting ANOVA with formula: semantic_soft_coverage_to_CQ ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                        sum_sq    df         F    PR(>F)    eta_sq
# C(KG)                0.018784   1.0  0.756059  0.398265  0.033071
# C(Complexity)        0.052860   2.0  1.063792  0.369797  0.093064
# C(Model)             0.079929   3.0  1.072372  0.390448  0.140722
# C(KG):C(Complexity)  0.043744   2.0  0.880348  0.435005  0.077016
# Residual             0.372674  15.0       NaN       NaN  0.656126
#
# Post-hoc: KG (Tukey HSD)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#    Big  Small    0.056 0.3951 -0.0778 0.1897  False
# ---------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#  Complex Moderate  -0.0998 0.4243 -0.2972 0.0975  False
#  Complex   Simple  -0.0006    1.0  -0.198 0.1968  False
# Moderate   Simple   0.0993 0.4284 -0.0981 0.2966  False
# -------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#     group1         group2     meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------
#    Big_Complex   Big_Moderate  -0.1886 0.5596 -0.5449 0.1678  False
#    Big_Complex     Big_Simple    0.003    1.0 -0.3534 0.3593  False
#    Big_Complex  Small_Complex  -0.0008    1.0 -0.3572 0.3555  False
#    Big_Complex Small_Moderate  -0.0119    1.0 -0.3683 0.3444  False
#    Big_Complex   Small_Simple   -0.005    1.0 -0.3613 0.3514  False
#   Big_Moderate     Big_Simple   0.1915 0.5438 -0.1648 0.5479  False
#   Big_Moderate  Small_Complex   0.1877 0.5641 -0.1686 0.5441  False
#   Big_Moderate Small_Moderate   0.1766 0.6236 -0.1797  0.533  False
#   Big_Moderate   Small_Simple   0.1836 0.5862 -0.1727 0.5399  False
#     Big_Simple  Small_Complex  -0.0038    1.0 -0.3601 0.3525  False
#     Big_Simple Small_Moderate  -0.0149    1.0 -0.3713 0.3414  False
#     Big_Simple   Small_Simple  -0.0079    1.0 -0.3643 0.3484  False
#  Small_Complex Small_Moderate  -0.0111    1.0 -0.3675 0.3452  False
#  Small_Complex   Small_Simple  -0.0041    1.0 -0.3605 0.3522  False
# Small_Moderate   Small_Simple    0.007    1.0 -0.3494 0.3633  False
# -------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 5.0000, p = 1
#     (paired t-test: t = -0.8868, p = 0.4405)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 1.0000, p = 0.25
#     (paired t-test: t = 1.0233, p = 0.3815)
#   Complex vs Simple: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = 0.0635, p = 0.9534)
#   Moderate vs Simple: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = -0.9308, p = 0.4206)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: tuple_cohesion
# ========================================================================================================================
# Attempting ANOVA with formula: tuple_cohesion ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                        sum_sq    df         F    PR(>F)    eta_sq
# C(KG)                0.029837   1.0  0.937354  0.348312  0.035494
# C(Complexity)        0.140225   2.0  2.202615  0.144975  0.166807
# C(Model)             0.129179   3.0  1.352741  0.295029  0.153668
# C(KG):C(Complexity)  0.063926   2.0  1.004129  0.389705  0.076044
# Residual             0.477473  15.0       NaN       NaN  0.567987
#
# Post-hoc: KG (Tukey HSD)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj  lower  upper reject
# -------------------------------------------------
#    Big  Small  -0.0705 0.378 -0.2331 0.092  False
# -------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#  Complex Moderate  -0.1865 0.1269 -0.4166 0.0437  False
#  Complex   Simple  -0.0784 0.6713 -0.3086 0.1517  False
# Moderate   Simple    0.108  0.476 -0.1222 0.3382  False
# -------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#     group1         group2     meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------
#    Big_Complex   Big_Moderate  -0.2668 0.3519 -0.6794 0.1457  False
#    Big_Complex     Big_Simple  -0.0341 0.9998 -0.4466 0.3785  False
#    Big_Complex  Small_Complex  -0.0945 0.9757 -0.5071  0.318  False
#    Big_Complex Small_Moderate  -0.2006 0.6415 -0.6132 0.2119  False
#    Big_Complex   Small_Simple  -0.2173 0.5643 -0.6299 0.1952  False
#   Big_Moderate     Big_Simple   0.2327 0.4941 -0.1798 0.6453  False
#   Big_Moderate  Small_Complex   0.1723 0.7669 -0.2403 0.5848  False
#   Big_Moderate Small_Moderate   0.0662 0.9951 -0.3464 0.4787  False
#   Big_Moderate   Small_Simple   0.0495 0.9988 -0.3631  0.462  False
#     Big_Simple  Small_Complex  -0.0604 0.9968  -0.473 0.3521  False
#     Big_Simple Small_Moderate  -0.1665 0.7903 -0.5791  0.246  False
#     Big_Simple   Small_Simple  -0.1832 0.7202 -0.5958 0.2293  False
#  Small_Complex Small_Moderate  -0.1061 0.9605 -0.5187 0.3064  False
#  Small_Complex   Small_Simple  -0.1228 0.9289 -0.5353 0.2898  False
# Small_Moderate   Small_Simple  -0.0167    1.0 -0.4292 0.3959  False
# -------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 1.0000, p = 0.25
#     (paired t-test: t = 1.2512, p = 0.2996)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = 1.4226, p = 0.25)
#   Complex vs Simple: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = 3.4163, p = 0.04196)
#   Moderate vs Simple: n = 4, W = 5.0000, p = 1
#     (paired t-test: t = -0.8807, p = 0.4433)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: determinism_score
# ========================================================================================================================
# Attempting ANOVA with formula: determinism_score ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                        sum_sq    df    F    PR(>F)    eta_sq
# C(KG)                0.041667   1.0  1.0  0.333170  0.043478
# C(Complexity)        0.083333   2.0  1.0  0.391127  0.086957
# C(Model)             0.125000   3.0  1.0  0.419866  0.130435
# C(KG):C(Complexity)  0.083333   2.0  1.0  0.391127  0.086957
# Residual             0.625000  15.0  NaN       NaN  0.652174
#
# Post-hoc: KG (Tukey HSD)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#    Big  Small   0.0833 0.3282 -0.0895 0.2562  False
# ---------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#  Complex Moderate   -0.125 0.4522 -0.3823 0.1323  False
#  Complex   Simple      0.0    1.0 -0.2573 0.2573  False
# Moderate   Simple    0.125 0.4522 -0.1323 0.3823  False
# -------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#     group1         group2     meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------
#    Big_Complex   Big_Moderate    -0.25 0.5297 -0.7087 0.2087  False
#    Big_Complex     Big_Simple      0.0    1.0 -0.4587 0.4587  False
#    Big_Complex  Small_Complex      0.0    1.0 -0.4587 0.4587  False
#    Big_Complex Small_Moderate      0.0    1.0 -0.4587 0.4587  False
#    Big_Complex   Small_Simple      0.0    1.0 -0.4587 0.4587  False
#   Big_Moderate     Big_Simple     0.25 0.5297 -0.2087 0.7087  False
#   Big_Moderate  Small_Complex     0.25 0.5297 -0.2087 0.7087  False
#   Big_Moderate Small_Moderate     0.25 0.5297 -0.2087 0.7087  False
#   Big_Moderate   Small_Simple     0.25 0.5297 -0.2087 0.7087  False
#     Big_Simple  Small_Complex      0.0    1.0 -0.4587 0.4587  False
#     Big_Simple Small_Moderate      0.0    1.0 -0.4587 0.4587  False
#     Big_Simple   Small_Simple      0.0    1.0 -0.4587 0.4587  False
#  Small_Complex Small_Moderate      0.0    1.0 -0.4587 0.4587  False
#  Small_Complex   Small_Simple      0.0    1.0 -0.4587 0.4587  False
# Small_Moderate   Small_Simple      0.0    1.0 -0.4587 0.4587  False
# -------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 0.0000, p = 0.3173
#     (paired t-test: t = -1.0000, p = 0.391)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /root/.local/lib/python3.10/site-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /root/.local/lib/python3.10/site-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
# /root/.local/lib/python3.10/site-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /root/.local/lib/python3.10/site-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# /root/.local/lib/python3.10/site-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /root/.local/lib/python3.10/site-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /root/.local/lib/python3.10/site-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 0.0000, p = 0.3173
#     (paired t-test: t = 1.0000, p = 0.391)
#   Complex vs Simple: Wilcoxon failed: zero_method 'wilcox' and 'pratt' do not work if x - y is zero for all elements.
#   Moderate vs Simple: n = 4, W = 0.0000, p = 0.3173
#     (paired t-test: t = -1.0000, p = 0.391)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: satisfiability_binding_score
# ========================================================================================================================
# Attempting ANOVA with formula: satisfiability_binding_score ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                        sum_sq    df         F    PR(>F)    eta_sq
# C(KG)                0.056733   1.0  1.066019  0.318207  0.044827
# C(Complexity)        0.226912   2.0  2.131868  0.153155  0.179295
# C(Model)             0.071379   3.0  0.447079  0.722971  0.056401
# C(KG):C(Complexity)  0.112269   2.0  1.054784  0.372728  0.088710
# Residual             0.798287  15.0       NaN       NaN  0.630767
#
# Post-hoc: KG (Tukey HSD)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#    Big  Small   0.0972 0.3206 -0.1012 0.2957  False
# ---------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#  Complex Moderate   0.0741 0.7853 -0.2062 0.3544  False
#  Complex   Simple   0.2331 0.1149 -0.0472 0.5134  False
# Moderate   Simple    0.159 0.3442 -0.1213 0.4393  False
# -------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#     group1         group2     meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------
#    Big_Complex   Big_Moderate  -0.0691 0.9974 -0.5631 0.4248  False
#    Big_Complex     Big_Simple   0.2368 0.6546 -0.2571 0.7308  False
#    Big_Complex  Small_Complex   0.0043    1.0 -0.4897 0.4982  False
#    Big_Complex Small_Moderate   0.2215 0.7122 -0.2724 0.7155  False
#    Big_Complex   Small_Simple   0.2336 0.6668 -0.2603 0.7276  False
#   Big_Moderate     Big_Simple   0.3059 0.3964  -0.188 0.7999  False
#   Big_Moderate  Small_Complex   0.0734 0.9966 -0.4206 0.5673  False
#   Big_Moderate Small_Moderate   0.2906 0.4499 -0.2033 0.7846  False
#   Big_Moderate   Small_Simple   0.3027 0.4073 -0.1912 0.7967  False
#     Big_Simple  Small_Complex  -0.2325 0.6709 -0.7265 0.2614  False
#     Big_Simple Small_Moderate  -0.0153    1.0 -0.5092 0.4787  False
#     Big_Simple   Small_Simple  -0.0032    1.0 -0.4971 0.4908  False
#  Small_Complex Small_Moderate   0.2173 0.7278 -0.2767 0.7112  False
#  Small_Complex   Small_Simple   0.2293  0.683 -0.2646 0.7233  False
# Small_Moderate   Small_Simple   0.0121    1.0 -0.4819  0.506  False
# -------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 1.0000, p = 0.285
# ...
#   wide_c = data.pivot_table(index="Model",
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#  Complex Moderate   0.0329 0.9224  -0.183 0.2488  False
#  Complex   Simple   0.0505 0.8273 -0.1654 0.2664  False
# Moderate   Simple   0.0176  0.977 -0.1983 0.2335  False
# -------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#     group1         group2     meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------
#    Big_Complex   Big_Moderate  -0.0426 0.9907 -0.2732 0.1881  False
#    Big_Complex     Big_Simple  -0.0751 0.8999 -0.3057 0.1555  False
#    Big_Complex  Small_Complex   0.1119 0.6439 -0.1188 0.3425  False
#    Big_Complex Small_Moderate   0.2202 0.0663 -0.0105 0.4508  False
#    Big_Complex   Small_Simple   0.2879 0.0099  0.0573 0.5186   True
#   Big_Moderate     Big_Simple  -0.0325 0.9973 -0.2632 0.1981  False
#   Big_Moderate  Small_Complex   0.1544 0.3172 -0.0762 0.3851  False
#   Big_Moderate Small_Moderate   0.2627 0.0204  0.0321 0.4934   True
#   Big_Moderate   Small_Simple   0.3305 0.0029  0.0998 0.5611   True
#     Big_Simple  Small_Complex    0.187 0.1541 -0.0437 0.4176  False
#     Big_Simple Small_Moderate   0.2953  0.008  0.0646 0.5259   True
#     Big_Simple   Small_Simple    0.363 0.0011  0.1324 0.5937   True
#  Small_Complex Small_Moderate   0.1083 0.6733 -0.1224 0.3389  False
#  Small_Complex   Small_Simple   0.1761 0.1991 -0.0546 0.4067  False
# Small_Moderate   Small_Simple   0.0678 0.9323 -0.1629 0.2984  False
# -------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = -5.8368, p = 0.01002)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 2.0000, p = 0.375
#     (paired t-test: t = -0.9780, p = 0.4002)
#   Complex vs Simple: n = 4, W = 1.0000, p = 0.25
#     (paired t-test: t = -2.2020, p = 0.115)
#   Moderate vs Simple: n = 4, W = 3.0000, p = 0.625
#     (paired t-test: t = -0.3648, p = 0.7395)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: syntax_ok_rate
# ========================================================================================================================
# Attempting ANOVA with formula: syntax_ok_rate ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                        sum_sq    df          F        PR(>F)    eta_sq
# C(KG)                0.037245   1.0   4.316603  5.533061e-02  0.019657
# C(Complexity)        0.046618   2.0   2.701469  9.953807e-02  0.024604
# C(Model)             1.648995   3.0  63.704511  9.146437e-09  0.870307
# C(KG):C(Complexity)  0.032445   2.0   1.880133  1.868065e-01  0.017124
# Residual             0.129425  15.0        NaN           NaN  0.068308
#
# Post-hoc: KG (Tukey HSD)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#    Big  Small   0.0788 0.5135 -0.1672 0.3248  False
# ---------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#  Complex Moderate   0.0148 0.9945 -0.3591 0.3886  False
#  Complex   Simple      0.1 0.7808 -0.2739 0.4739  False
# Moderate   Simple   0.0852  0.835 -0.2886 0.4591  False
# -------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#     group1         group2     meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------
#    Big_Complex   Big_Moderate  -0.0659 0.9996 -0.7723 0.6404  False
#    Big_Complex     Big_Simple    0.025    1.0 -0.6814 0.7314  False
#    Big_Complex  Small_Complex   -0.025    1.0 -0.7314 0.6814  False
#    Big_Complex Small_Moderate   0.0705 0.9995 -0.6359 0.7768  False
#    Big_Complex   Small_Simple     0.15 0.9826 -0.5564 0.8564  False
#   Big_Moderate     Big_Simple   0.0909 0.9983 -0.6154 0.7973  False
#   Big_Moderate  Small_Complex   0.0409    1.0 -0.6654 0.7473  False
#   Big_Moderate Small_Moderate   0.1364 0.9886   -0.57 0.8427  False
#   Big_Moderate   Small_Simple   0.2159 0.9212 -0.4904 0.9223  False
#     Big_Simple  Small_Complex    -0.05 0.9999 -0.7564 0.6564  False
#     Big_Simple Small_Moderate   0.0455 0.9999 -0.6609 0.7518  False
#     Big_Simple   Small_Simple    0.125 0.9923 -0.5814 0.8314  False
#  Small_Complex Small_Moderate   0.0955 0.9978 -0.6109 0.8018  False
#  Small_Complex   Small_Simple    0.175 0.9662 -0.5314 0.8814  False
# Small_Moderate   Small_Simple   0.0795 0.9991 -0.6268 0.7859  False
# -------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 1.0000, p = 0.25
#     (paired t-test: t = -1.4674, p = 0.2386)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = -0.4833, p = 0.662)
#   Complex vs Simple: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = -4.8323, p = 0.0169)
#   Moderate vs Simple: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = -2.8479, p = 0.06522)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: satisfiable_rate
# ========================================================================================================================
# Attempting ANOVA with formula: satisfiable_rate ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                        sum_sq    df          F        PR(>F)    eta_sq
# C(KG)                0.002764   1.0   0.264244  6.147090e-01  0.001280
# C(Complexity)        0.083334   2.0   3.982891  4.098030e-02  0.038573
# C(Model)             1.832308   3.0  58.382537  1.669605e-08  0.848132
# C(KG):C(Complexity)  0.085074   2.0   4.066059  3.882120e-02  0.039379
# Residual             0.156923  15.0        NaN           NaN  0.072636
#
# Post-hoc: KG (Tukey HSD)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#    Big  Small   0.0215 0.8682 -0.2437 0.2866  False
# ---------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#  Complex Moderate   -0.008 0.9986 -0.4043 0.3884  False
#  Complex   Simple   0.1208  0.726 -0.2755 0.5172  False
# Moderate   Simple   0.1288 0.6956 -0.2676 0.5251  False
# -------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#     group1         group2     meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------
#    Big_Complex   Big_Moderate  -0.0818 0.9992 -0.8289 0.6652  False
#    Big_Complex     Big_Simple   -0.025    1.0 -0.7721 0.7221  False
#    Big_Complex  Small_Complex   -0.125 0.9941 -0.8721 0.6221  False
#    Big_Complex Small_Moderate  -0.0591 0.9998 -0.8061  0.688  False
#    Big_Complex   Small_Simple   0.1417 0.9895 -0.6054 0.8887  False
#   Big_Moderate     Big_Simple   0.0568 0.9999 -0.6902 0.8039  False
#   Big_Moderate  Small_Complex  -0.0432    1.0 -0.7902 0.7039  False
#   Big_Moderate Small_Moderate   0.0227    1.0 -0.7243 0.7698  False
#   Big_Moderate   Small_Simple   0.2235 0.9275 -0.5236 0.9705  False
#     Big_Simple  Small_Complex     -0.1 0.9979 -0.8471 0.6471  False
#     Big_Simple Small_Moderate  -0.0341    1.0 -0.7811  0.713  False
#     Big_Simple   Small_Simple   0.1667 0.9784 -0.5804 0.9137  False
#  Small_Complex Small_Moderate   0.0659 0.9997 -0.6811  0.813  False
#  Small_Complex   Small_Simple   0.2667 0.8607 -0.4804 1.0137  False
# Small_Moderate   Small_Simple   0.2008 0.9527 -0.5463 0.9478  False
# -------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 2.0000, p = 0.593
#     (paired t-test: t = -0.6907, p = 0.5394)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = 0.3726, p = 0.7342)
#   Complex vs Simple: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = -3.5429, p = 0.03828)
#   Moderate vs Simple: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = -4.9332, p = 0.01597)
#
# ========================================================================================================================
# SHEET: H1-AM&C | METRIC: deterministic_rate
# ========================================================================================================================
# Attempting ANOVA with formula: deterministic_rate ~ C(KG) * C(Complexity) + C(Model)
#
# ANOVA table:
#                        sum_sq    df          F        PR(>F)    eta_sq
# C(KG)                0.037245   1.0   4.316603  5.533061e-02  0.019657
# C(Complexity)        0.046618   2.0   2.701469  9.953807e-02  0.024604
# C(Model)             1.648995   3.0  63.704511  9.146437e-09  0.870307
# C(KG):C(Complexity)  0.032445   2.0   1.880133  1.868065e-01  0.017124
# Residual             0.129425  15.0        NaN           NaN  0.068308
#
# Post-hoc: KG (Tukey HSD)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#    Big  Small   0.0788 0.5135 -0.1672 0.3248  False
# ---------------------------------------------------
#
# Post-hoc: Complexity (Tukey HSD)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /root/.local/lib/python3.10/site-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /root/.local/lib/python3.10/site-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#  Complex Moderate   0.0148 0.9945 -0.3591 0.3886  False
#  Complex   Simple      0.1 0.7808 -0.2739 0.4739  False
# Moderate   Simple   0.0852  0.835 -0.2886 0.4591  False
# -------------------------------------------------------
#
# Post-hoc: KG × Complexity combinations (Tukey HSD)
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#     group1         group2     meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------
#    Big_Complex   Big_Moderate  -0.0659 0.9996 -0.7723 0.6404  False
#    Big_Complex     Big_Simple    0.025    1.0 -0.6814 0.7314  False
#    Big_Complex  Small_Complex   -0.025    1.0 -0.7314 0.6814  False
#    Big_Complex Small_Moderate   0.0705 0.9995 -0.6359 0.7768  False
#    Big_Complex   Small_Simple     0.15 0.9826 -0.5564 0.8564  False
#   Big_Moderate     Big_Simple   0.0909 0.9983 -0.6154 0.7973  False
#   Big_Moderate  Small_Complex   0.0409    1.0 -0.6654 0.7473  False
#   Big_Moderate Small_Moderate   0.1364 0.9886   -0.57 0.8427  False
#   Big_Moderate   Small_Simple   0.2159 0.9212 -0.4904 0.9223  False
#     Big_Simple  Small_Complex    -0.05 0.9999 -0.7564 0.6564  False
#     Big_Simple Small_Moderate   0.0455 0.9999 -0.6609 0.7518  False
#     Big_Simple   Small_Simple    0.125 0.9923 -0.5814 0.8314  False
#  Small_Complex Small_Moderate   0.0955 0.9978 -0.6109 0.8018  False
#  Small_Complex   Small_Simple    0.175 0.9662 -0.5314 0.8814  False
# Small_Moderate   Small_Simple   0.0795 0.9991 -0.6268 0.7859  False
# -------------------------------------------------------------------
#
# Wilcoxon signed-rank tests for KG (pairwise across models):
#   Big vs Small: n = 4, W = 1.0000, p = 0.25
#     (paired t-test: t = -1.4674, p = 0.2386)
#
# Wilcoxon signed-rank tests for Complexity (pairwise across models):
#   Complex vs Moderate: n = 4, W = 4.0000, p = 0.875
#     (paired t-test: t = -0.4833, p = 0.662)
#   Complex vs Simple: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = -4.8323, p = 0.0169)
#   Moderate vs Simple: n = 4, W = 0.0000, p = 0.125
#     (paired t-test: t = -2.8479, p = 0.06522)
# /tmp/ipykernel_2035519/1104738204.py:106: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_kg = data.pivot_table(index="Model", columns="KG", values=metric)
# /tmp/ipykernel_2035519/1104738204.py:131: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   wide_c = data.pivot_table(index="Model",
